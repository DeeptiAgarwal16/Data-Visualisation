# %%
import pandas as pd
data=pd.read_csv("C:/Users/HP/Downloads/googleplaystore.csv")
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
data.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
data = data[-data.Rating.isnull()]
data.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       4
# Android Ver       3
# dtype: int64

# %%
data = data[-data['Content Rating'].isnull()]
data.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       4
# Android Ver       2
# dtype: int64

# %%
data = data[-data['Current Ver'].isnull()]
data.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       2
# dtype: int64

# %%
data = data[-data['Android Ver'].isnull()]
data.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data.Price = data.Price.apply(lambda x: 0 if x =='0' else float(x[1:]))
data['Price'].dtype
# Out:
# dtype('float64')

# %%
data.Reviews =  data.Reviews.astype("int32")

# %%
data['Reviews'].dtype
# Out:
# dtype('int32')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9360 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9360 non-null   object
#  1   Category        9360 non-null   object
#  2   Rating          9360 non-null   float64
#  3   Reviews         9360 non-null   int32
#  4   Size            9360 non-null   object
#  5   Installs        9360 non-null   object
#  6   Type            9360 non-null   object
#  7   Price           9360 non-null   float64
#  8   Content Rating  9360 non-null   object
#  9   Genres          9360 non-null   object
#  10  Last Updated    9360 non-null   object
#  11  Current Ver     9360 non-null   object
#  12  Android Ver     9360 non-null   object
# dtypes: float64(2), int32(1), object(10)
# memory usage: 987.2+ KB

# %%
data.Size = data.Size.apply(lambda x: 0 if x =='0' or x=='Varies with device' else float(x[:len(x)-2]))

# %%
data.Size
# Out:
# 0        1.0
# 1        1.0
# 2        8.0
# 3        2.0
# 4        2.0
#         ...
# 10834    2.0
# 10836    5.0
# 10837    3.0
# 10839    0.0
# 10840    1.0
# Name: Size, Length: 9360, dtype: float64

# %%
data.Installs = data.Installs.apply(lambda x: 0 if x =='0' else x[:len(x)-2])

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x=data['Price'],y=data['Rating'],hue=data['Size'])
# Out:
# <Axes: xlabel='Price', ylabel='Rating'>

# %%
data=data[data.Price<=50]

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x=data['Price'],y=data['Rating'],hue=data['Size'])
# Out:
# <Axes: xlabel='Price', ylabel='Rating'>

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x=data['Price'],y=data['Installs'],hue=data['Size'])
# Out:
# <Axes: xlabel='Price', ylabel='Installs'>

# %%
from sklearn.preprocessing import LabelEncoder
encoder= LabelEncoder()
data.Installs=encoder.fit_transform(data.Installs)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7552\1427124093.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Installs=encoder.fit_transform(data.Installs)

# %%
sns.lineplot(x=data['Rating'],y=data['Installs'])
# Out:
# <Axes: xlabel='Rating', ylabel='Installs'>
